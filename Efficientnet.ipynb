# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhrubanandi1256/CAR_SERVICE/blob/main/Efficientnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.applications import EfficientNetB0
model = EfficientNetB0(weights='imagenet')
# Out:
# ...
# 21834768/21834768 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb0"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  7           ['rescaling[0][0]']
#
#  rescaling_1 (Rescaling)        (None, 224, 224, 3)  0           ['normalization[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['rescaling_1[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 32  128         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (224, 224))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 224, 224, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# 1/1 [==============================] - 3s 3s/step
# predicted class:  [[5.81568893e-05 8.77007114e-05 8.45680042e-05 8.60244472e-05
#   4.03729828e-05 1.17917465e-04 3.28860770e-05 1.15191006e-05
#   3.61094026e-05 7.65101940e-05 1.18358830e-05 3.21126608e-05
#   3.18427701e-05 2.09907612e-05 2.13526528e-05 3.25852161e-05
#   1.23917504e-04 1.26118233e-04 9.26366047e-05 2.04732460e-05
#   4.28894855e-05 1.51961314e-04 2.65667622e-05 3.66540189e-05
#   4.32290835e-05 6.96520292e-05 1.25272665e-04 1.34212867e-04
#   1.43928846e-04 2.99266976e-05 8.13734805e-05 4.45621226e-05
#   5.46945485e-05 4.46770573e-05 5.12478618e-05 2.79315645e-05
#   8.44066890e-05 3.35638106e-05 7.04684280e-05 3.46873494e-05
#   4.35493166e-05 5.31610240e-05 5.24049101e-05 2.81103403e-05
#   5.57482526e-05 3.73814437e-05 8.08231998e-05 1.61548305e-04
#   1.01208798e-05 9.37580771e-05 4.45508631e-05 2.51333986e-04
#   6.41796796e-05 1.24734666e-04 9.26661960e-05 7.77485620e-05
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# ...
# 35363/35363 [==============================] - 0s 0us/step
# [[('n02124075', 'Egyptian_cat', 0.53746855),
#   ('n02123597', 'Siamese_cat', 0.10617867),
#   ('n02109961', 'Eskimo_dog', 0.042025868)]]

# %%
from tensorflow.keras.applications import EfficientNetB1
model = EfficientNetB1(weights='imagenet')
# Out:
# ...
# 32148312/32148312 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 240, 240, 3  0           []
#                                 )]
#
#  rescaling_2 (Rescaling)        (None, 240, 240, 3)  0           ['input_2[0][0]']
#
#  normalization_1 (Normalization  (None, 240, 240, 3)  7          ['rescaling_2[0][0]']
#  )
#
#  rescaling_3 (Rescaling)        (None, 240, 240, 3)  0           ['normalization_1[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 241, 241, 3)  0           ['rescaling_3[0][0]']
#
#  stem_conv (Conv2D)             (None, 120, 120, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 120, 120, 32  128         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (240, 240))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 240, 240, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# 1/1 [==============================] - 3s 3s/step
# predicted class:  [[6.22787484e-05 2.37066299e-04 1.16980482e-04 1.23979160e-04
#   1.58161041e-04 7.88783218e-05 5.36842090e-05 2.87044764e-04
#   1.56124428e-04 1.15918861e-04 4.53409593e-05 6.09617455e-05
#   3.94528361e-05 3.16639598e-05 5.08652520e-05 7.32342960e-05
#   2.12171741e-04 1.69170555e-04 7.32131375e-05 4.18301643e-05
#   1.37732888e-04 2.05824879e-04 9.60292527e-05 2.02513707e-04
#   3.04971418e-05 1.29480904e-04 2.03424250e-04 1.30120141e-04
#   1.08861990e-04 4.81966636e-05 1.46444363e-04 1.17589792e-04
#   1.49659987e-04 1.32431858e-04 7.14643174e-05 1.21137920e-04
#   2.04478943e-04 9.37186269e-05 8.95607154e-05 9.03630134e-05
#   7.97279281e-05 4.32123561e-05 1.03826234e-04 4.23730417e-05
#   8.85672926e-05 3.93038972e-05 8.76766426e-05 2.02726747e-04
#   4.15022223e-05 1.25742430e-04 1.66384605e-04 3.60311533e-04
#   8.68327916e-05 1.75730544e-04 1.72437081e-04 1.53961053e-04
# ...

# %% [markdown]
# **B2**

# %%
from tensorflow.keras.applications import EfficientNetB2
model = EfficientNetB2(weights='imagenet')
# Out:
# ...
# 37432240/37432240 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 260, 260, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 260, 260, 3)  0           ['input_3[0][0]']
#
#  normalization_2 (Normalization  (None, 260, 260, 3)  7          ['rescaling_4[0][0]']
#  )
#
#  rescaling_5 (Rescaling)        (None, 260, 260, 3)  0           ['normalization_2[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 261, 261, 3)  0           ['rescaling_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 130, 130, 32  864         ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 130, 130, 32  128         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (260, 260))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 260, 260, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# 1/1 [==============================] - 2s 2s/step
# predicted class:  [[4.41059128e-05 2.21962866e-04 4.85615928e-05 9.83923455e-05
#   1.65711361e-04 1.42457066e-04 9.49469613e-05 3.51746334e-04
#   1.07893553e-04 2.21876093e-04 6.77944045e-05 1.95323315e-04
#   1.08198765e-04 4.81660863e-05 1.84394172e-04 9.94650400e-05
#   4.49226733e-04 1.52282926e-04 1.02429687e-04 7.02448451e-05
#   2.03023068e-04 1.52405250e-04 7.01946847e-05 8.44644965e-05
#   8.23428782e-05 1.76968199e-04 2.30584628e-04 2.06107055e-04
#   1.57330782e-04 9.96746166e-05 7.61311094e-05 1.79173992e-04
#   2.16699336e-04 1.15294846e-04 1.12294947e-04 1.30248081e-04
#   1.59548217e-04 1.01959835e-04 1.51738917e-04 1.32733927e-04
#   1.43656740e-04 1.41483848e-04 1.29195483e-04 2.15754801e-04
#   9.86091472e-05 1.45536818e-04 3.47301742e-04 2.15953667e-04
#   5.05483440e-05 9.00057566e-05 2.48174241e-04 2.24349278e-04
#   1.18278396e-04 1.79953655e-04 1.64432218e-04 2.03448886e-04
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.33623716),
#   ('n02123597', 'Siamese_cat', 0.32377532),
#   ('n04590129', 'window_shade', 0.0390265)]]

# %% [markdown]
# **B3**

# %%
from tensorflow.keras.applications import EfficientNetB3
model = EfficientNetB3(weights='imagenet')
# Out:
# ...
# 50095040/50095040 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 300, 300, 3  0           []
#                                 )]
#
#  rescaling_6 (Rescaling)        (None, 300, 300, 3)  0           ['input_4[0][0]']
#
#  normalization_3 (Normalization  (None, 300, 300, 3)  7          ['rescaling_6[0][0]']
#  )
#
#  rescaling_7 (Rescaling)        (None, 300, 300, 3)  0           ['normalization_3[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 301, 301, 3)  0           ['rescaling_7[0][0]']
#
#  stem_conv (Conv2D)             (None, 150, 150, 40  1080        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 150, 150, 40  160         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (300, 300))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 300, 300, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# 1/1 [==============================] - 4s 4s/step
# predicted class:  [[6.90652087e-05 2.78664520e-04 2.05365606e-04 2.30713529e-04
#   5.83146350e-04 3.55497061e-04 3.79536388e-04 4.51543747e-04
#   2.93882273e-04 8.01157003e-05 9.70503170e-05 4.57277667e-04
#   1.75856796e-04 1.53036919e-04 2.27299170e-04 1.87747472e-04
#   5.81840635e-04 2.77803367e-04 6.85812789e-04 4.50888365e-05
#   1.13301983e-04 2.00273309e-04 6.56373813e-05 9.82974307e-05
#   1.35405717e-04 2.69105425e-04 7.70630504e-05 1.08734326e-04
#   1.86811230e-04 1.20488854e-04 2.28392804e-04 1.15869349e-04
#   2.58118700e-04 1.79421244e-04 3.02158383e-04 3.25878093e-04
#   2.05474338e-04 3.03340843e-04 1.45309576e-04 1.46322564e-04
#   4.15887189e-04 2.38915163e-04 1.72810134e-04 1.83392360e-04
#   2.42913695e-04 4.48146457e-05 3.15842044e-04 2.03940654e-04
#   2.11466213e-05 1.42138015e-04 2.13114108e-04 1.43875281e-04
#   1.33566675e-04 7.95318629e-05 1.54188514e-04 1.83726283e-04
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.15014721),
#   ('n03793489', 'mouse', 0.050714403),
#   ('n04590129', 'window_shade', 0.04766347)]]

# %% [markdown]
# **B4**

# %%
from tensorflow.keras.applications import EfficientNetB4
model = EfficientNetB4(weights='imagenet')
# Out:
# ...
# 78864416/78864416 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_5 (InputLayer)           [(None, 380, 380, 3  0           []
#                                 )]
#
#  rescaling_8 (Rescaling)        (None, 380, 380, 3)  0           ['input_5[0][0]']
#
#  normalization_4 (Normalization  (None, 380, 380, 3)  7          ['rescaling_8[0][0]']
#  )
#
#  rescaling_9 (Rescaling)        (None, 380, 380, 3)  0           ['normalization_4[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 381, 381, 3)  0           ['rescaling_9[0][0]']
#
#  stem_conv (Conv2D)             (None, 190, 190, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 190, 190, 48  192         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (380, 380))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 380, 380, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6d3fd23b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 4s 4s/step
# predicted class:  [[1.32429195e-04 3.00390442e-04 1.82569464e-04 8.95282137e-05
#   3.05452937e-04 2.88180570e-04 7.88692487e-05 1.35297902e-04
#   8.31758298e-05 1.11031004e-04 8.29185083e-05 2.97172635e-04
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.36188716),
#   ('n02123597', 'Siamese_cat', 0.24379487),
#   ('n04589890', 'window_screen', 0.027737563)]]

# %% [markdown]
# **B5**

# %%
from tensorflow.keras.applications import EfficientNetB5
model = EfficientNetB5(weights='imagenet')
# Out:
# ...
# 123465288/123465288 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_6 (InputLayer)           [(None, 456, 456, 3  0           []
#                                 )]
#
#  rescaling_10 (Rescaling)       (None, 456, 456, 3)  0           ['input_6[0][0]']
#
#  normalization_5 (Normalization  (None, 456, 456, 3)  7          ['rescaling_10[0][0]']
#  )
#
#  rescaling_11 (Rescaling)       (None, 456, 456, 3)  0           ['normalization_5[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 457, 457, 3)  0           ['rescaling_11[0][0]']
#
#  stem_conv (Conv2D)             (None, 228, 228, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 228, 228, 48  192         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (456, 456))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 456, 456, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd6cfd55630> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 8s 8s/step
# predicted class:  [[5.35445142e-05 1.21832236e-04 4.26526203e-05 9.98489340e-05
#   1.04900981e-04 2.33748069e-04 1.18883741e-04 1.44190635e-04
#   8.10695419e-05 9.27215442e-05 3.24470093e-05 2.30838064e-04
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# [[('n02123597', 'Siamese_cat', 0.32221785),
#   ('n02124075', 'Egyptian_cat', 0.15384626),
#   ('n04590129', 'window_shade', 0.1032613)]]

# %% [markdown]
# **B6**

# %%
from tensorflow.keras.applications import EfficientNetB6
model = EfficientNetB6(weights='imagenet')
# Out:
# ...
# 174460376/174460376 [==============================] - 3s 0us/step

# %%
model.summary()
# Out:
# Model: "efficientnetb6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_8 (InputLayer)           [(None, 528, 528, 3  0           []
#                                 )]
#
#  rescaling_14 (Rescaling)       (None, 528, 528, 3)  0           ['input_8[0][0]']
#
#  normalization_7 (Normalization  (None, 528, 528, 3)  7          ['rescaling_14[0][0]']
#  )
#
#  rescaling_15 (Rescaling)       (None, 528, 528, 3)  0           ['normalization_7[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 529, 529, 3)  0           ['rescaling_15[0][0]']
#
#  stem_conv (Conv2D)             (None, 264, 264, 56  1512        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 264, 264, 56  224         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (528, 528))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 528, 528, 3)

# %%
preds=model.predict(x)
print("predicted class: ", preds )
# Out:
# 1/1 [==============================] - 8s 8s/step
# predicted class:  [[5.01200411e-05 1.51407745e-04 3.24673492e-05 8.05227828e-05
#   2.69286247e-04 2.15871900e-04 8.42428199e-05 1.40810385e-04
#   4.81457173e-05 1.30308836e-04 8.73894824e-05 2.28492878e-04
#   9.00914965e-05 1.32428948e-04 1.03002880e-04 1.24682469e-04
#   1.19066033e-04 2.41523318e-04 2.02691954e-04 1.12889109e-04
#   1.16789917e-04 1.68366605e-04 6.71012895e-05 1.43582569e-04
#   7.75335502e-05 1.42645062e-04 1.37453710e-04 6.74429248e-05
#   1.07151100e-04 1.36499075e-04 8.69602518e-05 1.42513978e-04
#   1.82035816e-04 1.32270536e-04 1.38454503e-04 7.40979085e-05
#   1.82290838e-04 1.23287478e-04 2.58693006e-04 1.46448263e-04
#   1.03451290e-04 1.22289202e-04 2.40404988e-04 1.16563380e-04
#   7.83907308e-05 1.43020603e-04 1.19836339e-04 3.33036209e-04
#   9.42514307e-05 1.39834825e-04 1.01200378e-04 1.13196569e-04
#   2.94880301e-04 2.17519977e-04 3.87202570e-04 2.61589041e-04
# ...

# %%
decode_predictions(preds,top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.4682023),
#   ('n02123597', 'Siamese_cat', 0.21260764),
#   ('n02123045', 'tabby', 0.01914278)]]

# %% [markdown]
# **B7**

# %%
from tensorflow.keras.applications import EfficientNetB7
modelb7 = EfficientNetB7(weights='imagenet')
# Out:
# ...
# 268326632/268326632 [==============================] - 2s 0us/step

# %%
modelb7.summary()
# Out:
# Model: "efficientnetb7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_9 (InputLayer)           [(None, 600, 600, 3  0           []
#                                 )]
#
#  rescaling_16 (Rescaling)       (None, 600, 600, 3)  0           ['input_9[0][0]']
#
#  normalization_8 (Normalization  (None, 600, 600, 3)  7          ['rescaling_16[0][0]']
#  )
#
#  rescaling_17 (Rescaling)       (None, 600, 600, 3)  0           ['normalization_8[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 601, 601, 3)  0           ['rescaling_17[0][0]']
#
#  stem_conv (Conv2D)             (None, 300, 300, 64  1728        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 300, 300, 64  256         ['stem_conv[0][0]']
#                                 )
#
# ...

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input


img_path = '/content/unseen_imagenet (1).jfif'

img = cv2.imread(img_path)
img = cv2.resize(img, (600, 600))

x = np.expand_dims(img, axis=0)
x = preprocess_input(x)

print('Input image shape:', x.shape)

my_image = imread(img_path)
imshow(my_image)
# Out:
# Input image shape: (1, 600, 600, 3)

# %%
predb7=modelb7.predict(x)
print("predicted class: ", predb7 )
# Out:
# 1/1 [==============================] - 11s 11s/step
# predicted class:  [[1.52137261e-04 8.52253725e-05 2.08263940e-04 7.06465653e-05
#   7.28741798e-05 2.32819395e-04 7.07315048e-05 1.33674112e-04
#   6.31875155e-05 9.05730703e-05 1.23822800e-04 2.81480810e-04
#   7.73658903e-05 5.84869049e-05 1.69225212e-04 4.76842943e-05
#   9.16598583e-05 4.63122007e-04 1.89612634e-04 1.11401474e-04
#   7.16552095e-05 4.85150289e-04 4.37381677e-05 4.81676761e-05
#   8.50165015e-05 8.01058923e-05 6.23686865e-05 1.99143731e-04
#   1.80900315e-04 1.68287021e-04 7.56766312e-05 3.68832523e-04
#   1.34840913e-04 4.16303483e-05 1.50494918e-04 5.42441412e-05
#   1.11833433e-04 1.65475678e-04 2.18350964e-04 1.25319057e-04
#   1.82202843e-04 1.89018363e-04 1.19506076e-04 9.21676474e-05
#   8.95909689e-05 5.37829110e-05 5.34556457e-04 2.22929710e-04
#   6.73665636e-05 1.93352680e-04 9.76310766e-05 1.49112588e-04
#   1.94578082e-04 2.65512324e-04 8.99134029e-05 2.03842676e-04
# ...

# %%
decode_predictions(predb7,top=3)
# Out:
# [[('n02124075', 'Egyptian_cat', 0.4578841),
#   ('n02123597', 'Siamese_cat', 0.2893461),
#   ('n02123159', 'tiger_cat', 0.014280196)]]
